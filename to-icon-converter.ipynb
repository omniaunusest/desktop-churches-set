# %%
from PIL import Image
import os
import time
import sys

def print_slow(text, delay=0.05, line_delay=0.5):
    for line in text.split('\n'):
        for char in line:
            sys.stdout.write(char)
            sys.stdout.flush()
            time.sleep(delay)
        print()  # Salto de línea al final de cada línea
        time.sleep(line_delay)  # Pausa entre líneas



print("""   
                                p r e s e n t s
                ░█▀█░█▄█░█▀█░▀█▀░█▀█░░░█░█░█▀█░█░█░█▀▀░░░█▀▀░█▀▀░▀█▀
                ░█░█░█░█░█░█░░█░░█▀█░░░█░█░█░█░█░█░▀▀█░░░█▀▀░▀▀█░░█░
                ░▀▀▀░▀░▀░▀░▀░▀▀▀░▀░▀░░░▀▀▀░▀░▀░▀▀▀░▀▀▀░░░▀▀▀░▀▀▀░░▀░""")
print_slow(""""
    "\n                         .ICO IS OUR ONLY FAITH""",
    delay=0.04, line_delay=0.10
)  

ascii_art = r"""
    .                     .                    .
  .                                 *                .      .         *
                         =        .            =                   
            .         <^\O|^                 ^|O/^>          *
     .         *      \/  |/                 \|  \|                .        .     *
                       /__|      .  '  .      |__\     *
            =           ll     .    |          ll           =                     
         <^\O|^     ¡__/||       '  |  '       ||\__¡     ^|O/^>      .         *  ·
         \/  |/   ¡_/_| ||  .  '  \ | / '  .   || |_\_¡   \|  \/
  .       /__|  ¡_||_||_||      -== + ==-      ||_||_||_¡  |__\    .       ·
         ..ll   //-|--|-||  '  .  / . \  .  '  ||-|--|-\\   ll..
        (____) /|  |  | ||       .  |  .       || |  |  |\ (____)              
         |  |¡//|  |  | ||    '     |     '    || |  |  |\\¡| -|          .  ·
         | -|¡  |  |  | ||       '  .  '       || |  |  | \¡|  |
         |  ||  |  |  | ||                     || |  |  |  || -|
    ¡_¡__|- ||  |  |  | ||   *      +          || |  |  |  ||  |__¡_¡
    ¡_|__|__||__|__|__|_||          A          ||_|__|__|__||__|__|_¡
    ·-|--|--||--|--|--|-||       _ /_\__  *    ||-|--|--|--||--|--|-·
      |  |  ||  |  |  | ||      /|-'O'-|\      || |  |  |  || -|  |
      |  |- ||  |  |  | ||     _||-----||_     || |  |  |  ||  |  |
      |  |  ||  |  |  | ||     /||=====||\     || |  |  |  ||- |  |
      |  | -||  |  |  | ||  __|I_I_[_]_I_I|__  || |  |  |  ||  |  |
     _|__|__||__|__|__|_||:::::::::::::::::::::||_|__|__|__||__|__|_
www  -|--|--||--|--|--|-||::::::::::::::::www::||-|--|--|--||--|--|-  www   wwwwwww
  ww =|==|==||==|==|==|=||::::::::::::www::::::||=|==|==|==||==|==|= wwwwwwwwwww  www
wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww
"""
# this ASCII art is a modified version of The Pearly Gates by Joan G. Stark

print_slow(ascii_art, delay=0.9, line_delay=0)

print_slow(
    "\n                     WELCOME TO THE CONVERSION PROGRAM",
    delay=0.05, line_delay=0.10
)

print_slow(
    "\nPlease:\nGather in my destiny the wayward image you want to turn into an icon. Take all the time you need. Time is all we got.",
    delay=0.05, line_delay=0.10
)

def to_ico(start, output, size=(256, 256)):
    try:
        imagen = Image.open(start)
        imagen = imagen.resize(size, Image.LANCZOS)
        imagen.save(output, format='ICO')
        print(f"\nYou have a new icon! It has been congregated here: {os.path.abspath(output)}")
    except Exception as e:
        print(f"\nError: {e}")

def obtener_nombre_archivo(mensaje, extension_default=""):
    while True:
        nombre = input(mensaje).strip()
        if not os.path.splitext(nombre)[1] and extension_default:
            nombre += extension_default
        if extension_default == ".ico" or os.path.exists(nombre):
            return nombre
        print(f"The file '{nombre}' no existe. Inténtalo de nuevo.")

entrada = input("\n> ¿Cómo se llama el archivo que quieres entregar? (ej: imagen.png): ")
salida = input("> ¿Cómo lo quieres bautizar? (ej: icono.ico): ")

to_ico(entrada, salida)

# %%
from PIL import Image  # (Python Imaging Library) Adds image processing capabilities.

import os  # Enables portable path handling across different operating systems and execution environments.

import time # Controls the timing (delay) between character output, essential for creating a rhythmic text effect.
import sys  # Provides direct control over standard output, allowing characters to be displayed immediately.

            # Together, 'time' and 'sys' emulate the character-by-character text display of early computer terminals,
            # where each character appeared sequentially due to hardware limitations and slower processing speeds.


class IconCongregator:
    def __init__(self):
        
        self.default_size = (256, 256) # Our default size for icons

    def print_slow(self, text, delay=0.05, line_delay=0.5):
   
        for line in text.split('\n'):
            for char in line:
                sys.stdout.write(char)  # print step by step
                sys.stdout.flush()  # sudden print
                time.sleep(delay)
            print()  # extra empty print after a line
            time.sleep(line_delay)  # pause between lines

    def congregate_icon(self, input_path, output_path):
   
        try:
            imagen = Image.open(input_path)  # open image
            imagen = imagen.resize(self.default_size, Image.LANCZOS)  # resize image
            imagen.save(output_path, format='ICO')  # save as .ICO
            print(f"\nYour icon has been congregated here: {os.path.abspath(output_path)}") 
            return True
        except Exception as e:
            print(f"\nError during congregation: {e}") 
            return False

    def get_file_name(self, prompt, default_extension=""):
     
    
        while True:
            name = input(prompt).strip()  # name of the file 
                                          # if there is no extension, .png is default
            if not os.path.splitext(name)[1] and default_extension:
                name += default_extension
            # Si es un archivo de salida (.ico) o el archivo de entrada existe, lo devuelve
            if default_extension == ".ico" or os.path.exists(name):
                return name
            print(f"File '{name}' not found. Try again.")  # Error if not found.

        # aquí hay que añadir una condición que permita la salida (si no pedirá un nombre hasta el infinito)

    def run(self):

        #Runs the main program:
        # displays ASCII art, prompts the user for files and performs the conversion.

       
        print("""
                                p r e s e n t s
                ░█▀█░█▄█░█▀█░▀█▀░█▀█░░░█░█░█▀█░█░█░█▀▀░░░█▀▀░█▀▀░▀█▀
                ░█░█░█░█░█░█░░█░░█▀█░░░█░█░█░█░█░█░▀▀█░░░█▀▀░▀▀█░░█░
                ░▀▀▀░▀░▀░▀░▀░▀▀▀░▀░▀░░░▀▀▀░▀░▀░▀▀▀░▀▀▀░░░▀▀▀░▀▀▀░░▀░
        """)
        
        self.print_slow("""
                        .ICO EXTENSION IS OUR ONLY FAITH
        """, delay=0.04, line_delay=0.10)

        
        ascii_art = r"""
    .                     .                    .
  .                                 *                .      .         *
                         =        .            =                   
            .         <^\O|^                 ^|O/^>          *
     .         *      \/  |/                 \|  \|                .        .     *
                       /__|      .  '  .      |__\     *
            =           ll     .    |          ll           =                     
         <^\O|^     ¡__/||       '  |  '       ||\__¡     ^|O/^>      .         *  ·
         \/  |/   ¡_/_| ||  .  '  \ | / '  .   || |_\_¡   \|  \/
  .       /__|  ¡_||_||_||      -== + ==-      ||_||_||_¡  |__\    .       ·
         ..ll   //-|--|-||  '  .  / . \  .  '  ||-|--|-\\   ll..
        (____) /|  |  | ||       .  |  .       || |  |  |\ (____)              
         |  |¡//|  |  | ||    '     |     '    || |  |  |\\¡| -|          .  ·
         | -|¡  |  |  | ||       '  .  '       || |  |  | \¡|  |
         |  ||  |  |  | ||                     || |  |  |  || -|
    ¡_¡__|- ||  |  |  | ||   *      +          || |  |  |  ||  |__¡_¡
    ¡_|__|__||__|__|__|_||          A          ||_|__|__|__||__|__|_¡
    ·-|--|--||--|--|--|-||       _ /_\__  *    ||-|--|--|--||--|--|-·
      |  |  ||  |  |  | ||      /|-'O'-|\      || |  |  |  || -|  |
      |  |- ||  |  |  | ||     _||-----||_     || |  |  |  ||  |  |
      |  |  ||  |  |  | ||     /||=====||\     || |  |  |  ||- |  |
      |  | -||  |  |  | ||  __|I_I_[_]_I_I|__  || |  |  |  ||  |  |
     _|__|__||__|__|__|_||:::::::::::::::::::::||_|__|__|__||__|__|_
www  -|--|--||--|--|--|-||::::::::::::::::www::||-|--|--|--||--|--|-  www   wwwwwww
  ww =|==|==||==|==|==|=||::::::::::::www::::::||=|==|==|==||==|==|= wwwwwwwwwww  www
wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww]
        """

        self.print_slow(ascii_art, delay=0.01, line_delay=0)

        self.print_slow(
            "                 W E L C O M E   T O   T H E   C O N V E R S I O N   P R O G R A M",
            delay=0.04, line_delay=0.10
        )

        print_slow("Please:\nGather in my destiny the wayward image you want to turn into an icon. Take all the time you need. Time is all we have.",
    delay=0.05, line_delay=0.10)

       
        while True:
            
            input_path = self.get_file_name(
                "\n> What is the name of the file you wish to join in our faith? (e.g., image.png): ",
                ".png"
            )
            
            output_path = self.get_file_name(
                "\n> How shall we baptize your icon?")

           
            if self.congregate_icon(input_path, output_path):
                print("X")

            
            if input("Do you wish to join another icon? (Y/N): ").strip().lower() != 'y':
                print("Time is all we got. Use it wisely... or don't. It's not like we're counting.")
                break

# Punto de entrada del programa
if __name__ == "__main__":
    congregator = IconCongregator()  
    congregator.run()  # Ejecuta el programa
# Out:
#                                 p r e s e n t s
#                 ░█▀█░█▄█░█▀█░▀█▀░█▀█░░░█░█░█▀█░█░█░█▀▀░░░█▀▀░█▀▀░▀█▀
#                 ░█░█░█░█░█░█░░█░░█▀█░░░█░█░█░█░█░█░▀▀█░░░█▀▀░▀▀█░░█░
#                 ░▀▀▀░▀░▀░▀░▀░▀▀▀░▀░▀░░░▀▀▀░▀░▀░▀▀▀░▀▀▀░░░▀▀▀░▀▀▀░░▀░
#
#
#                         .ICO EXTENSION IS OUR ONLY FAITH
#
#
#     .                     .                    .
#   .                                 *                .      .         *
#                          =        .            =
#             .         <^\O|^                 ^|O/^>          *
#      .         *      \/  |/                 \|  \|                .        .     *
#                        /__|      .  '  .      |__\     *
#             =           ll     .    |          ll           =
#          <^\O|^     ¡__/||       '  |  '       ||\__¡     ^|O/^>      .         *  ·
#          \/  |/   ¡_/_| ||  .  '  \ | / '  .   || |_\_¡   \|  \/
#   .       /__|  ¡_||_||_||      -== + ==
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 151
#     149 if __name__ == "__main__":
#     150     congregator = IconCongregator()  # Crea una instancia de la clase
# --> 151     congregator.run()  # Ejecuta el programa
#
# Cell In[1], line 119, in IconCongregator.run(self)
#      85         self.print_slow("""
#      86                         .ICO EXTENSION IS OUR ONLY FAITH
#      87         """, delay=0.04, line_delay=0.10)
#      90         ascii_art = r"""
#      91     .                     .                    .
#      92   .                                 *                .      .         *
#    (...)    116 wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww]
#     117         """
# --> 119         self.print_slow(ascii_art, delay=0.01, line_delay=0)
#     121         self.print_slow(
#     122             "                 W E L C O M E   T O   T H E   C O N V E R S I O N   P R O G R A M",
#     123             delay=0.04, line_delay=0.10
#     124         )
#     126         # Bucle principal: pide archivos y realiza conversiones hasta que el usuario decida salir
#
# Cell In[1], line 29, in IconCongregator.print_slow(self, text, delay, line_delay)
#      27     sys.stdout.write(char)  # print step by step
#      28     sys.stdout.flush()  # sudden print
# ---> 29     time.sleep(delay)
#      30 print()  # extra empty print after a line
#      31 time.sleep(line_delay)
#
# KeyboardInterrupt:
